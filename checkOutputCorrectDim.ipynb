# %%
import pandas as pd

# %%
df = pd.read_csv('output.csv')

print(df.head())
print(df.shape)
print(df.loc[0]["item_list"])
print(len(df.loc[0]["item_list"].split(" ")))
# Out:
#    user_id                                          item_list
# 0        0  2628 1399 6018 1445 4351 2399 4312 1656 5258 4...
# 1        1  3142 4936 3460 6810 2907 1949 2295 6165 403 20...
# 2        2  5323 1252 5640 4264 1373 2167 2557 1038 5489 4...
# 3        3  479 1554 531 262 4161 2844 2653 5252 5326 3617...
# 4        4  4373 5069 4484 6684 1302 4532 2472 5356 5460 3...
# (27095, 2)
# 2628 1399 6018 1445 4351 2399 4312 1656 5258 4200 5965 3824 5532 1983 5442 1171 3607 1252 1943 3602
# 20
